# %%
using Plots, DifferentialEquations
using LinearAlgebra
using NLopt
using .Threads 
using Interpolations
using Distributions
using Roots
gr();

# %%
a=zeros(9) #parameter vector for unknown parameters
λ1g=0.002; λ2g=0.002; δg=0.0; KKg=80.0; C0g=[1.0,1.0]; σg=1.0; #initial parameter estimates

# %%
t1=[0
769
1140
1488
1876
2233
2602
2889
3213
3621
4028
] #observation times

data11=[0.748717949
0.97235023
5.490243902
17.89100529
35
56.38256703
64.55087666
66.61940299
71.67362453
80.47179487
79.88291457
]; #data 1


data12=[1.927065527
0.782795699
1.080487805
2.113227513
3.6
2.74790376
2.38089652
1.8
0.604574153
1.305128205
1.700502513]; #data 2

# %%
function DE!(dC,C,p,t) #function to define process model
λ1,λ2,δ,KK=p #parameter vector for the process model
S=C[1]+C[2]
dC[1]=λ1*C[1]*(1.0-S/KK) #define differential equations
dC[2]=λ2*C[2]*(1.0-S/KK)-δ*C[2]*C[1]/KK; #define differential equations
end
# Out:
# DE! (generic function with 1 method)

# %%
function odesolver(t1,λ1,λ2,δ,KK,C01,C02) #function to solve the process model
p=(λ1,λ2,δ,KK) # parameter vector for the process model
C0=[C01,C02]
tspan=(0.0,maximum(t1))  #time horizon
prob=ODEProblem(DE!,C0,tspan,p) #define ODE model
sol=solve(prob,saveat=t1)  #solve and save solutions
return sol[1,:],sol[2,:]
end
# Out:
# odesolver (generic function with 1 method)

# %%
function odesolver2(t1,λ1,λ2,δ,KK,C01,C02) #function to solve the process model
p=(λ1,λ2,δ,KK) # parameter vector for the process model
C0=[C01,C02]
tspan=(0.0,maximum(t1)) #time horizon
prob=ODEProblem(DE!,C0,tspan,p) #define ODE model
sol=solve(prob)  #solve and save solutions, including the time
tt=sol.t[:]
return sol[1,:],sol[2,:],tt
end
# Out:
# odesolver2 (generic function with 1 method)

# %%
function model(t1,a) #function to solve the process model
y1=zeros(length(t1))
y2=zeros(length(t1))
(y1,y2)=odesolver(t1,a[1],a[2],a[3],a[4],a[5],a[6]) #solve the process model
return y1,y2
end
# Out:
# model (generic function with 1 method)

# %%
function error(data11,data12,a) #function to evaluate the loglikelihood for the data given parameters a
y1=zeros(length(t1))
y2=zeros(length(t1))
(y1,y2)=model(t1,a);
e=0.0;
f=0.0;
dist1=Normal(0.0,a[7]);
e=loglikelihood(dist1,data11-y1)+loglikelihood(dist1,data12-y2);
return e
end
# Out:
# error (generic function with 1 method)

# %%
function fun(a) #function to evaluate the loglikelihood as a function of the parameters a 
return error(data11,data12,a)
end
# Out:
# fun (generic function with 1 method)

# %%
function optimise(fun,θ₀,lb,ub;  #NLopt routine to maximise the function fun, with parameter estimates \theta_0 subject to bound constraints lb, ub
    dv = false,
    method = dv ? :LD_LBFGS : :LN_BOBYQA,
)

if dv || String(method)[2] == 'D'
    tomax = fun
else
    tomax = (θ,∂θ) -> fun(θ)
end

opt = Opt(method,length(θ₀))
opt.local_optimizer = Opt(:LN_NELDERMEAD, length(θ₀))
opt.max_objective = tomax
opt.lower_bounds = lb       # Lower bound
opt.upper_bounds = ub       # Upper bound
opt.maxtime=2*60 #max comp time
res = optimize(opt,θ₀)
return res[[2,1]]
end
# Out:
# optimise (generic function with 1 method)

# %%
θG =[λ1g,  λ2g,  δg,  KKg,   C0g[1], C0g[2], σg] #parameter estimates
lb=[0.00,  0.00, 0.00, 60.0,  0.0, 0.0, 0.0]; #lower bound
ub=[0.01,  0.01, 0.01, 90.0, 1.0, 1.0, 3.0]; #upper bound
(xopt,fopt)  = optimise(fun,θG,lb,ub) #call numerical optimization routine to give the vector of parameters xopt, and the maximum loglikelihood fopt
fmle=fopt
λ1mle=xopt[1]
λ2mle=xopt[2]
δmle=xopt[3]
Kmle=xopt[4]
C01mle=xopt[5]
C02mle=xopt[6]
σmle=xopt[7]
fopt
#xopt
# Out:
# -44.52148956654379

# %%
y1mle=zeros() 
y2mle=zeros()
tt=zeros()
(y1mle,y2mle,tt)=odesolver2(t1,xopt[1],xopt[2],xopt[3],xopt[4],xopt[5],xopt[6]) #evaluate the solution at the mle  
p1=scatter(t1,data11,legend=false,msw=0,ms=7,color=:red,msa=:red,markershape=:diamond)
p1=plot!(tt,y1mle,color=:firebrick2,xlabel="t [days]",ylabel="C_1(t) [%]",legend=false,lw=4,xlims=(-100,4100),ylims=(0,100),xticks=[0,2000,4000],yticks=[0,50,100])
p2=scatter(t1,data12,legend=false,msw=0,ms=7,color=:green,msa=:green,markershape=:hexagon)
p2=plot!(tt,y2mle,color=:aqua,xlabel="t [days]",ylabel="C_2(t) [%]",legend=false,lw=4,xlims=(-100,4100),ylims=(0,10),xticks=[0,2000,4000],yticks=[0,5,10])
p3=scatter(t1,data11.+data12,legend=false,msw=0,ms=7,color=:blue,msa=:blue)
p3=plot!(tt,y1mle.+y2mle,color=:fuchsia,xlabel="t [days]",ylabel="S(t) [%]",legend=false,lw=4,xlims=(-100,4100),ylims=(0,100),xticks=[0,2000,4000],yticks=[0,50,100])
p4=plot(p1,p2,p3,layout=(1,3),legend=false) #plot the data and solutions 
display(p4)
savefig(p4, "mle2.pdf")

# %%
#Profile λ1
nptss=40 #points on the profile
λ1min=0.002  #lower bound for the profile - can be changed easily
λ1max=0.004 #upper bound for the profile - can be changed easily
λ1range=LinRange(λ1min,λ1max,nptss) #vector of λ1 values along the profile
nrange=zeros(6,nptss); #matrix to store the nuisance parameters once optimized out
llλ1=zeros(nptss); #loglikelihood at each point along the profile
nllλ1=zeros(nptss); #normalised loglikelihood at each point along the profile
predictC1λ1=zeros(length(tt),nptss) #vector to store predictions at each point along the profile
predictC2λ1=zeros(length(tt),nptss) #vector to store predictions at each point along the profile


for i in 1:nptss
function fun1(aa) #function to return loglikelihood by fixing the interest parameter along the profile
return error(data11,data12,[λ1range[i],aa[1],aa[2],aa[3],aa[4],aa[5],aa[6]])
end

lb1=    [λ2mle,δmle,Kmle,C01mle,C02mle,σmle]/2.0; #lower bound
ub1=2.0*[λ2mle,δmle,Kmle,C01mle,C02mle,σmle]; #upper bound
θG1 = [λ2mle,δmle,Kmle,C01mle,C02mle,σmle] #initial estimate - take the MLE 
local (xo,fo)=optimise(fun1,θG1,lb1,ub1) #numerical optimisation
nrange[:,i]=xo[:] #store the nuisance parameters
llλ1[i]=fo[1] #store the loglikelihood
(predictC1λ1[:,i],predictC2λ1[:,i])=model(tt,[λ1range[i],nrange[1,i],nrange[2,i],nrange[3,i],nrange[4,i],nrange[5,i],nrange[6,i]])
end

nllλ1=llλ1.-maximum(llλ1); #calculate normalised loglikelihood



C1λ1p=zeros(length(tt))
C1λ1m=1000*ones(length(tt))
C2λ1p=zeros(length(tt))
C2λ1m=1000*ones(length(tt))


for i in 1:nptss
if nllλ1[i] >= -1.921  #for all predictions where the normalised loglikelihood is above the threshold calculate the maximum/minimum predictions
    for j in 1:length(tt)
    C1λ1p[j]=max(predictC1λ1[j,i],C1λ1p[j])
    C1λ1m[j]=min(predictC1λ1[j,i],C1λ1m[j])
    C2λ1p[j]=max(predictC2λ1[j,i],C2λ1p[j])
    C2λ1m[j]=min(predictC2λ1[j,i],C2λ1m[j])

        end
end

end

s1=plot(λ1range,nllλ1,xlim=(λ1min,λ1max),ylim=(-3,0.1),lw=4,xlabel="λ_1 [/days]",ylabel="ll",legend=false)
s1=hline!([-1.92],lw=4)
s1=vline!([λ1mle],lw=4)
#display(s1)

# %%
#Profile λ2
λ2min=0.0020
λ2max=0.0040
λ2range=LinRange(λ2min,λ2max,nptss)
nrange=zeros(6,nptss);
llλ2=zeros(nptss);
nllλ2=zeros(nptss);
predictC1λ2=zeros(length(tt),nptss)
predictC2λ2=zeros(length(tt),nptss)


for i in 1:nptss
function fun2(aa)
return error(data11,data12,[aa[1],λ2range[i],aa[2],aa[3],aa[4],aa[5],aa[6]])
end
lb1=[λ1mle,δmle,Kmle,C01mle,C02mle,σmle]/1.5;
ub1=1.5*[λ1mle,δmle,Kmle,C01mle,C02mle,σmle];
θG1 = [λ1mle,δmle,Kmle,C01mle,C02mle,σmle]
local (xo,fo)=optimise(fun2,θG1,lb1,ub1)
nrange[:,i]=xo[:]
llλ2[i]=fo[1]
(predictC1λ2[:,i],predictC2λ2[:,i])=model(tt,[nrange[1,i],λ2range[i],nrange[2,i],nrange[3,i],nrange[4,i],nrange[5,i],nrange[6,i]])

end

nllλ2=llλ2.-maximum(llλ2);

C1λ2p=zeros(length(tt))
C1λ2m=1000*ones(length(tt))
C2λ2p=zeros(length(tt))
C2λ2m=1000*ones(length(tt))


for i in 1:nptss
if nllλ2[i] >= -1.921
    for j in 1:length(tt)
    C1λ2p[j]=max(predictC1λ2[j,i],C1λ2p[j])
    C1λ2m[j]=min(predictC1λ2[j,i],C1λ2m[j])
    C2λ2p[j]=max(predictC2λ2[j,i],C2λ2p[j])
    C2λ2m[j]=min(predictC2λ2[j,i],C2λ2m[j])

        end
end

end

s2=plot(λ2range,nllλ2,xlim=(λ2min,λ2max),ylim=(-3,0.1),xlabel="λ2 [/day]",ylabel="ll",legend=false,lw=4)
s2=hline!([-1.92],lw=4)
s2=vline!([λ2mle],lw=4)
#display(s2)

# %%
#Profile δ
δmin=0.0
δmax=0.005
δrange=LinRange(δmin,δmax,nptss)
nrange=zeros(6,nptss);
llδ=zeros(nptss);
nllδ=zeros(nptss);
predictC1δ=zeros(length(tt),nptss)
predictC2δ=zeros(length(tt),nptss)

for i in 1:nptss
function fun3(aa)
return error(data11,data12,[aa[1],aa[2],δrange[i],aa[3],aa[4],aa[5],aa[6]])
end

lb1=    [λ1mle,λ2mle,Kmle,C01mle,C02mle,σmle]/1.5;
ub1=1.5*[λ1mle,λ2mle,Kmle,C01mle,C02mle,σmle];
θG1 = [λ1mle,λ2mle,Kmle,C01mle,C02mle,σmle]
local (xo,fo)=optimise(fun3,θG1,lb1,ub1)
nrange[:,i]=xo[:]
llδ[i]=fo[1]
(predictC1δ[:,i],predictC2δ[:,i])=model(tt,[nrange[1,i],nrange[2,i],δrange[i],nrange[3,i],nrange[4,i],nrange[5,i],nrange[6,i]])
end

nllδ=llδ.-maximum(llδ);

C1δp=zeros(length(tt))
C1δm=1000*ones(length(tt))
C2δp=zeros(length(tt))
C2δm=1000*ones(length(tt))


for i in 1:nptss
if nllδ[i] >= -1.921
    for j in 1:length(tt)
    C1δp[j]=max(predictC1δ[j,i],C1δp[j])
    C1δm[j]=min(predictC1δ[j,i],C1δm[j])
    C2δp[j]=max(predictC2δ[j,i],C2δp[j])
    C2δm[j]=min(predictC2δ[j,i],C2δm[j])

        end
end

end


s3=plot(δrange,nllδ,xlim=(δmin,δmax),ylim=(-3,0.1),xlabel="δ [/day]",ylabel="ll",legend=false,lw=4)
s3=hline!([-1.92],lw=4)
s3=vline!([δmle],lw=4)
#display(s3)

# %%
#Profile K
Kmin=75
Kmax=83
Krange=LinRange(Kmin,Kmax,nptss)
nrange=zeros(6,nptss);
llK=zeros(nptss);
nllK=zeros(nptss);
predictC1K=zeros(length(tt),nptss)
predictC2K=zeros(length(tt),nptss)

for i in 1:nptss
function fun4(aa)
return error(data11,data12,[aa[1],aa[2],aa[3],Krange[i],aa[4],aa[5],aa[6]])
end

lb1= [λ1mle,λ2mle,δmle,C01mle,C02mle,σmle]/1.5;
ub1=1.5*[λ1mle,λ2mle,δmle,C01mle,C02mle,σmle];
θG1 = [λ1mle,λ2mle,δmle,C01mle,C02mle,σmle]
local (xo,fo)=optimise(fun4,θG1,lb1,ub1)
nrange[:,i]=xo[:]
llK[i]=fo[1]
(predictC1K[:,i],predictC2K[:,i])=model(tt,[nrange[1,i],nrange[2,i],nrange[3,i],Krange[i],nrange[4,i],nrange[5,i],nrange[6,i]])
end

nllK=llK.-maximum(llK);


C1Kp=zeros(length(tt))
C1Km=1000*ones(length(tt))
C2Kp=zeros(length(tt))
C2Km=1000*ones(length(tt))


for i in 1:nptss
if nllK[i] >= -1.921
    for j in 1:length(tt)
    C1Kp[j]=max(predictC1K[j,i],C1Kp[j])
    C1Km[j]=min(predictC1K[j,i],C1Km[j])
    C2Kp[j]=max(predictC2K[j,i],C2Kp[j])
    C2Km[j]=min(predictC2K[j,i],C2Km[j])

        end
end

end

s4=plot(Krange,nllK,xlim=(Kmin,Kmax),ylim=(-3,0,1),xlabel="K [%]",ylabel="ll",legend=false,lw=4)
s4=hline!([-1.92],lw=4)
s4=vline!([Kmle],lw=4)
#display(s4)

# %%
#Profile C10
C01min=0.1
C01max=0.8
C01range=LinRange(C01min,C01max,nptss)
nrange=zeros(6,nptss);
llC01=zeros(nptss);
nllC01=zeros(nptss);
predictC1C01=zeros(length(tt),nptss)
predictC2C01=zeros(length(tt),nptss)

for i in 1:nptss
function fun5(aa)
return error(data11,data12,[aa[1],aa[2],aa[3],aa[4],C01range[i],aa[5],aa[6]])
end

lb1=    [λ1mle,λ2mle,δmle,Kmle,C02mle,σmle]/1.5;
ub1=1.5*[λ1mle,λ2mle,δmle,Kmle,C02mle,σmle];
θG1 = [λ1mle,λ2mle,δmle,Kmle,C02mle,σmle]
local (xo,fo)=optimise(fun5,θG1,lb1,ub1)
nrange[:,i]=xo[:]
llC01[i]=fo[1]
(predictC1C01[:,i],predictC2C01[:,i])=model(tt,[nrange[1,i],nrange[2,i],nrange[3,i],nrange[4,i],C01range[i],nrange[5,i],nrange[6,i]])
end

nllC01=llC01.-maximum(llC01);

C1C01p=zeros(length(tt))
C1C01m=1000*ones(length(tt))
C2C01p=zeros(length(tt))
C2C01m=1000*ones(length(tt))


for i in 1:nptss
if nllC01[i] >= -1.921
    for j in 1:length(tt)
    C1C01p[j]=max(predictC1C01[j,i],C1C01p[j])
    C1C01m[j]=min(predictC1C01[j,i],C1C01m[j])
    C2C01p[j]=max(predictC2C01[j,i],C2C01p[j])
    C2C01m[j]=min(predictC2C01[j,i],C2C01m[j])

        end
end

end

s5=plot(C01range,nllC01,xlim=(C01min,C01max),ylim=(-3,0.1),xlabel="C1(0) [%]",ylabel="ll",legend=false,lw=4)
s5=hline!([-1.92],lw=4)
s5=vline!([C01mle],lw=4)
#display(s5)

# %%
#Profile C20
C02min=0.0003
C02max=0.5
C02range=LinRange(C02min,C02max,nptss)
nrange=zeros(6,nptss);
llC02=zeros(nptss);
nllC02=zeros(nptss);
predictC1C02=zeros(length(tt),nptss)
predictC2C02=zeros(length(tt),nptss)


for i in 1:nptss
function fun6(aa)
return error(data11,data12,[aa[1],aa[2],aa[3],aa[4],aa[5],C02range[i],aa[6]])
end

lb1=    [λ1mle,λ2mle,δmle,Kmle,C01mle,σmle]/1.5;
ub1=1.5*[λ1mle,λ2mle,δmle,Kmle,C01mle,σmle];
θG1 = [λ1mle,λ2mle,δmle,Kmle,C01mle,σmle]
local (xo,fo)=optimise(fun6,θG1,lb1,ub1)
nrange[:,i]=xo[:]
llC02[i]=fo[1]
(predictC1C02[:,i],predictC2C02[:,i])=model(tt,[nrange[1,i],nrange[2,i],nrange[3,i],nrange[4,i],nrange[5,i],C02range[i],nrange[6,i]])    
end

nllC02=llC02.-maximum(llC02);


C1C02p=zeros(length(tt))
C1C02m=1000*ones(length(tt))
C2C02p=zeros(length(tt))
C2C02m=1000*ones(length(tt))


for i in 1:nptss
if nllC02[i] >= -1.921
    for j in 1:length(tt)
    C1C02p[j]=max(predictC1C02[j,i],C1C02p[j])
    C1C02m[j]=min(predictC1C02[j,i],C1C02m[j])
    C2C02p[j]=max(predictC2C02[j,i],C2C02p[j])
    C2C02m[j]=min(predictC2C02[j,i],C2C02m[j])

        end
end

end


s6=plot(C02range,nllC02,xlim=(C02min,C02max),ylim=(-3,0.1),xlabel="C2(0) [%]",ylabel="ll",legend=false,lw=4)
s6=hline!([-1.92],lw=4)
s6=vline!([C02mle],lw=4)
#display(s6)

# %%
#Profile σ=1.0
σmin=0.1
σmax=3.0
σrange=LinRange(σmin,σmax,nptss)
nrange=zeros(6,nptss);
llσ=zeros(nptss);
nllσ=zeros(nptss);

for i in 1:nptss
function fun7(aa)
return error(data11,data12,[aa[1],aa[2],aa[3],aa[4],aa[5],aa[6],σrange[i]])
end

lb1=    [λ1mle,λ2mle,δmle,Kmle,C01mle,C02mle]/1.5;
ub1=1.5*[λ1mle,λ2mle,δmle,Kmle,C01mle,C02mle];
θG1 = [λ1mle,λ2mle,δmle,Kmle,C01mle,C02mle]
local (xo,fo)=optimise(fun7,θG1,lb1,ub1)
nrange[:,i]=xo[:]
llσ[i]=fo[1]
end

nllσ=llσ.-maximum(llσ);


s7=plot(σrange,nllσ,xlim=(σmin,σmax),ylim=(-3,0.1),xlabel="σ [%]",ylabel="ll",legend=false,lw=4)
s7=hline!([-1.92],lw=4)
s7=vline!([σmle],lw=4)
#display(s7)


f1=LinearInterpolation(σrange,nllσ);
aa=2.5;
bb=3.0;
while (bb-aa) >= 0.00000001
cc = (aa+bb)/2.0
    if sign(f1(cc)+1.92) == sign(f1(aa)+1.92)
        aa=cc
    else
        bb=cc
    end
end

# %%
s8=plot(s1,s2,s3,s4,s5,s6,s7,s7,layout=(2,4),legend=false)
display(s8)
#savefig(s8,"profiles2.pdf")

# %%
r1=plot(tt,y1mle,w=0,c=:blue,ribbon=(y1mle.-C1λ1m,C1λ1p.-y1mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,100),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C1(t) [%]")
r2=plot(tt,y2mle,w=0,c=:blue,ribbon=(y2mle.-C2λ1m,C2λ1p.-y2mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,10),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C2(t) [%]")
r3=plot(tt,y1mle.+y2mle,w=0,c=:blue,ribbon=((y1mle.+y2mle).-(C1λ1m.+C2λ1m),(C1λ1p.+C2λ1p).-(y1mle.+y2mle)),fillalpha=.5,xlim=(0,4500),xticks=[0,1000,2000,3000,4000],ylim=(0,100),legend=false,xlabel="t",ylabel="S(t)")
r4=plot(r1,r2,layout=(1,2),legend=false)
display(r4)
savefig(r4,"Intervals2Lambda1.pdf") #plot the prediction interval about the MLE in terms of the λ1 parameter

# %%
r1=plot(tt,y1mle,w=0,c=:blue,ribbon=(y1mle.-C1λ2m,C1λ2p.-y1mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,100),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C1(t) [%]")
r2=plot(tt,y2mle,w=0,c=:blue,ribbon=(y2mle.-C2λ2m,C2λ2p.-y2mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,10),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C2(t) [%]")
r3=plot(tt,y1mle.+y2mle,w=0,c=:blue,ribbon=((y1mle.+y2mle).-(C1λ2m.+C2λ2m),(C1λ2p.+C2λ2p).-(y1mle.+y2mle)),fillalpha=.5,xlim=(0,4500),xticks=[0,1000,2000,3000,4000],ylim=(0,100),legend=false,xlabel="t",ylabel="S(t)")
r4=plot(r1,r2,layout=(1,2),legend=false)
display(r4)
savefig(r4,"Intervals2Lambda2.pdf") #plot the prediction interval about the MLE in terms of the λ2 parameter

# %%
r1=plot(tt,y1mle,w=0,c=:blue,ribbon=(y1mle.-C1δm,C1δp.-y1mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,100),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C1(t) [%]")
r2=plot(tt,y2mle,w=0,c=:blue,ribbon=(y2mle.-C2δm,C2δp.-y2mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,10),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C2(t) [%]")
r3=plot(tt,y1mle.+y2mle,w=0,c=:blue,ribbon=((y1mle.+y2mle).-(C1δm.+C2δm),(C1δp.+C2δp).-(y1mle.+y2mle)),fillalpha=.5,xlim=(0,4500),xticks=[0,1000,2000,3000,4000],ylim=(0,100),legend=false,xlabel="t",ylabel="S(t)")
r4=plot(r1,r2,layout=(1,2),legend=false)
display(r4)
savefig(r4,"Intervals2d2.pdf") #plot the prediction interval about the MLE in terms of the δ parameter

# %%
r1=plot(tt,y1mle,w=0,c=:blue,ribbon=(y1mle.-C1Km,C1Kp.-y1mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,100),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C1(t) [%]")
r2=plot(tt,y2mle,w=0,c=:blue,ribbon=(y2mle.-C2Km,C2Kp.-y2mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,10),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C2(t) [%]")
r3=plot(tt,y1mle.+y2mle,w=0,c=:blue,ribbon=((y1mle.+y2mle).-(C1Km.+C2Km),(C1Kp.+C2Kp).-(y1mle.+y2mle)),fillalpha=.5,xlim=(0,4500),xticks=[0,1000,2000,3000,4000],ylim=(0,100),legend=false,xlabel="t",ylabel="S(t)")
r4=plot(r1,r2,layout=(1,2),legend=false)
display(r4)
savefig(r4,"Intervals2K.pdf") #plot the prediction interval about the MLE in terms of the K parameter

# %%
r1=plot(tt,y1mle,w=0,c=:blue,ribbon=(y1mle.-C1C01m,C1C01p.-y1mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,100),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C1(t) [%]")
r2=plot(tt,y2mle,w=0,c=:blue,ribbon=(y2mle.-C2C01m,C2C01p.-y2mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,10),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C2(t) [%]")
r3=plot(tt,y1mle.+y2mle,w=0,c=:blue,ribbon=((y1mle.+y2mle).-(C1C01m.+C2C01m),(C1C01p.+C2C01p).-(y1mle.+y2mle)),fillalpha=.5,xlim=(0,4500),xticks=[0,1000,2000,3000,4000],ylim=(0,100),legend=false,xlabel="t",ylabel="S(t)")
r4=plot(r1,r2,layout=(1,2),legend=false)
display(r4)
savefig(r4,"Intervals2C01.pdf") #plot the prediction interval about the MLE in terms of the C1(0) parameter

# %%
r1=plot(tt,y1mle,w=0,c=:blue,ribbon=(y1mle.-C1C02m,C1C02p.-y1mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,100),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C1(t) [%]")
r2=plot(tt,y2mle,w=0,c=:blue,ribbon=(y2mle.-C2C02m,C2C02p.-y2mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,10),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C2(t) [%]")
r3=plot(tt,y1mle.+y2mle,w=0,c=:blue,ribbon=((y1mle.+y2mle).-(C1C02m.+C2C02m),(C1C02p.+C2C02p).-(y1mle.+y2mle)),fillalpha=.5,xlim=(0,4500),xticks=[0,1000,2000,3000,4000],ylim=(0,100),legend=false,xlabel="t",ylabel="S(t)")
r4=plot(r1,r2,layout=(1,2),legend=false)
display(r4)
savefig(r4,"Intervals2C02.pdf") #plot the prediction interval about the MLE in terms of the C2(0) parameter

# %%
C1Up=zeros(length(tt))
C1Um=zeros(length(tt))
for i in 1:length(tt)
C1Up[i] = max(C1λ1p[i],C1λ1p[i],C1δp[i],C1Kp[i],C1C01p[i],C1C02p[i])
C1Um[i] = min(C1λ1m[i],C1λ1m[i],C1δm[i],C1Km[i],C1C01m[i],C1C02m[i])
end

C2Up=zeros(length(tt))
C2Um=zeros(length(tt))
for i in 1:length(tt)
C2Up[i] = max(C2λ1p[i],C2λ1p[i],C2δp[i],C2Kp[i],C2C01p[i],C2C02p[i])
C2Um[i] = min(C2λ1m[i],C2λ1m[i],C2δm[i],C2Km[i],C2C01m[i],C2C02m[i])
end #Take the union of the parameterwise profile intervals 



qq5=plot(tt,y1mle,w=0,c=:blue,ribbon=(y1mle.-C1Um,C1Up.-y1mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,100),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C1(t) [%]")
qq6=plot(tt,y2mle,w=0,c=:blue,ribbon=(y2mle.-C2Um,C2Up.-y2mle),fillalpha=1.0,xlim=(0,4500),ylim=(0,10),xticks=[0,1000,2000,3000,4000],legend=false,xlabel="t [days]",ylabel="C2(t) [%]")
qq7=plot(tt,y1mle.+y2mle,w=0,c=:blue,ribbon=((y1mle.+y2mle).-(C1Um.+C2Um),(C1Up.+C2Up).-(y1mle.+y2mle)),fillalpha=1.0,xlim=(0,4500),xticks=[0,1000,2000,3000,4000],ylim=(0,100),legend=false,xlabel="t [days]",ylabel="S(t) [%]")
rr4=plot(qq5,qq6,layout=(1,2),legend=false)
display(rr4)
savefig(rr4, "Union3.pdf")

# %%
display(qq7)
